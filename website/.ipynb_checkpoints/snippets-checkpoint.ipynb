# %%
import csv

entries = Entry.objects.all()

with open('cards.csv', 'wb') as csvfile:
    cardswriter = csv.writer(csvfile, delimiter='#', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for e in entries[:4]:
        cardswriter.writerow([e.title, e.image, e.image.width, e.image.height])


#with open('cards.csv') as csvfile:
#    reader = csv.reader(csvfile, delimiter=' ', quotechar='|', quoting=csv.QUOTE_MINIMAL)
#    for row in reader:
#        print (row[0])

# %%
entries = Entry.objects.all()
e = entries[0]
e.image.width
e.image.height
# Out:
# 1347

# %%
import re
from datetime import datetime

date_object = datetime.strptime('Jun 1 2005  1:33PM', '%b %d %Y %I:%M%p')

entries = Entry.objects.all()
total = 0
for e in entries:    
    # match 4 digits at start of portrayed_object_date
    m = re.findall('^(\d{4})', str(e.portrayed_object_date))
    if m:
        total = total + 1
        date = datetime.strptime(m[0], '%Y')
        print (date)
        e.date = date
        e.save()
print ("total: %s") % (total)
# Out:
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1571-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1544-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1665-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1551-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1547-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1617-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1614-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1577-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1739-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1675-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1624-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1498-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1680-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1562-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1506-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1529-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1704-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1676-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1852-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1834-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1510-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1650-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1726-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
# 1571-01-01 00:00:00
# 1544-01-01 00:00:00
# 1665-01-01 00:00:00
# 1665-01-01 00:00:00
# 1551-01-01 00:00:00
# 1547-01-01 00:00:00
# 1617-01-01 00:00:00
# 1614-01-01 00:00:00
# 1577-01-01 00:00:00
# 1739-01-01 00:00:00
# 1739-01-01 00:00:00
# 1675-01-01 00:00:00
# 1675-01-01 00:00:00
# 1624-01-01 00:00:00
# 1624-01-01 00:00:00
# 1624-01-01 00:00:00
# 1624-01-01 00:00:00
# 1665-01-01 00:00:00
# 1665-01-01 00:00:00
# 1665-01-01 00:00:00
# 1577-01-01 00:00:00
# 1498-01-01 00:00:00
# 1680-01-01 00:00:00
# 1680-01-01 00:00:00
# 1562-01-01 00:00:00
# 1665-01-01 00:00:00
# 1547-01-01 00:00:00
# 1617-01-01 00:00:00
# 1617-01-01 00:00:00
# 1617-01-01 00:00:00
# 1617-01-01 00:00:00
# 1617-01-01 00:00:00
# 1617-01-01 00:00:00
# 1665-01-01 00:00:00
# 1547-01-01 00:00:00
# 1624-01-01 00:00:00
# 1562-01-01 00:00:00
# 1562-01-01 00:00:00
# 1617-01-01 00:00:00
# 1506-01-01 00:00:00
# 1624-01-01 00:00:00
# 1624-01-01 00:00:00
# 1624-01-01 00:00:00
# 1624-01-01 00:00:00
# 1617-01-01 00:00:00
# 1529-01-01 00:00:00
# 1571-01-01 00:00:00
# 1704-01-01 00:00:00
# 1529-01-01 00:00:00
# 1617-01-01 00:00:00
# 1676-01-01 00:00:00
# 1571-01-01 00:00:00
# 1562-01-01 00:00:00
# 1852-01-01 00:00:00
# 1834-01-01 00:00:00
# 1510-01-01 00:00:00
# 1544-01-01 00:00:00
# 1562-01-01 00:00:00
# 1577-01-01 00:00:00
# 1562-01-01 00:00:00
# 1650-01-01 00:00:00
# 1665-01-01 00:00:00
# 1562-01-01 00:00:00
# 1726-01-01 00:00:00
# 1571-01-01 00:00:00
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1651-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1528-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1684-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1636-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
#
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/__init__.py:1453: RuntimeWarning: DateTimeField Entry.date received a naive datetime (1672-01-01 00:00:00) while time zone support is active.
#   RuntimeWarning)
# 1624-01-01 00:00:00
# 1651-01-01 00:00:00
# 1510-01-01 00:00:00
# 1562-01-01 00:00:00
# 1571-01-01 00:00:00
# 1528-01-01 00:00:00
# 1528-01-01 00:00:00
# 1684-01-01 00:00:00
# 1624-01-01 00:00:00
# 1577-01-01 00:00:00
# 1624-01-01 00:00:00
# 1636-01-01 00:00:00
# 1672-01-01 00:00:00
# 1672-01-01 00:00:00
# total: 79

# %% [markdown]
# # Import CSV annotations

# %%
import csv
import os
import re

entries = Entry.objects.all()
#print( os.path.basename (entries[0].image.name) )
        
path = '/home/stahl/icst/soundcolourspace/annotations.csv'

class MyDialect(csv.Dialect):
    strict = True
    skipinitialspace = True
    quoting = csv.QUOTE_ALL
    delimiter = ';'
    quotechar = '"'
    lineterminator = '\n'


with open(path, 'rb') as csvfile:
    r=csv.reader(csvfile, MyDialect())
    for i in r:
        #print ("#%s: %s \n\n%s") % (i[2], i[0], i[1])
        
        entries = Entry.objects.filter(image__icontains=i[0])
        if (len(entries) == 0):
            print ("no entries for %s") % i[0]
        elif (len(entries) > 1):
            print ("multiple entries for %s") % i[0]
        else:
            entries[0].description = unicode(i[1], errors='ignore')
            entries[0].save()
            
    
        #print ('####################################################################################')

# %% [markdown]
# # MEDIENARCHIV

# %%
import json
import sys
import os
import requests
import shutil
import operator
from collections import OrderedDict
from requests.auth import HTTPBasicAuth

import tempfile
from django.core.files.base import ContentFile
from django.core.files import File

base = 'http://medienarchiv.zhdk.ch'
collection_id = '73114b11-08de-42a9-ba36-864d9c1b5641'

user = 'sound-colour-space'
password = '95ca2a71-4e01-4477-8e14-b673e96e4fe9'
auth_header = 'Authorization: Basic c291bmQtY29sb3VyLXNwYWNlOjk1Y2EyYTcxLTRlMDEtNDQ3Ny04ZTE0LWI2NzNlOTZlNGZlOQ=='

auth = HTTPBasicAuth(user, password)

#if r.status_code == 200

def get_authors(relations):
    # for each author
    author_objs = []
    for key, values in relations.iteritems():
        a = requests.get(base+values.get('href'), auth=auth).json()
        #print ("\tauthor: %s %s (%s) [%s %s]") % (a.get('first_name'), a.get('last_name'), a.get('pseudonym'), a.get('date_of_birth'), a.get('date_of_death'))
        new_author = { 'first_name': a.get('first_name'), 'last_name': a.get('last_name'), 'pseudonym': a.get('pseudonym'), 'date_of_birth': a.get('date_of_birth'), 'date_of_death': a.get('date_of_death') }
        
        # create or update license
        obj, created = Author.objects.update_or_create(
            remote_uuid=a.get('id'), defaults=new_author)
        author_objs.append(obj) # add to list for update even if existing
        
    return author_objs
        
def get_licenses(relations):
    # for each license
    license_objs = []
    for key, values in relations.iteritems():
        
        l = requests.get(base+values.get('href'), auth=auth).json()
        #print ("\tlicence (%s): %s, %s, %s") % (l.get('id'), l.get('label'), l.get('url'), l.get('usage'))
        
        new_license = { 'remote_uuid': l.get('id'), 'label': l.get('label'), 'url': l.get('url'), 'usage': l.get('usage') }
        # create or update license
        obj, created = License.objects.update_or_create(
            remote_uuid=l.get('id'), defaults=new_license)
        license_objs.append(obj) # add to list for update even if existing
    
    return license_objs
        
        
def get_entry(key, href):
    # get single entry
    entry_request = requests.get(base+href, auth=auth)
    entry = entry_request.json()
    
    print ('Madek: %s') % entry.get('id')
    
    # the updated entry as dict
    new_entry = {}
    
    # get meta data
    meta_data = requests.get(base + href + '/meta-data/', auth=auth)
    meta_data = meta_data.json()
    
    author_objs = []
    license_objs = []

    # iterate over meta-data
    for m in meta_data.get('meta-data'):
        key = m.get('meta_key_id')
        id = m.get('id')
        if (key == 'madek_core:title'):
            title = requests.get(base+'/api/meta-data/'+id, auth=auth).json().get('value')
            #print('madek_core:title: %s') % title
            new_entry['title'] = title
        elif (key == 'madek_core:subtitle'):
            subtitle = requests.get(base+'/api/meta-data/'+id, auth=auth).json().get('value')
            #print('madek_core:subtitle: %s') % subtitle
            new_entry['subtitle'] = subtitle
        elif (key == 'madek_core:portrayed_object_date'):
            portrayed_object_date = requests.get(base+'/api/meta-data/'+id, auth=auth).json().get('value')
            #print('madek_core:portrayed_object_date: %s') % portrayed_object_date
            new_entry['portrayed_object_date'] = portrayed_object_date
        
        elif (key == 'madek_core:authors'):
            authors = requests.get(base+'/api/meta-data/'+id, auth=auth).json().get('_json-roa')['collection']
            #print('madek_core:authors: %s') % authors
            author_objs = get_authors(authors['relations'])
            
        elif (key == 'copyright:license'):    
            licenses = requests.get(base+'/api/meta-data/'+id, auth=auth).json().get('_json-roa')['collection']
            #print('copyright:license: %s') % licenses
            license_objs = get_licenses(licenses['relations']) # will be set at the end of this function
            
        elif (key == 'copyright:source'):
            source = requests.get(base+'/api/meta-data/'+id, auth=auth).json().get('value')
            #print('copyright:source: %s') % source
            new_entry['source'] = source
            
        elif (key == 'copyright:copyright_usage'):
            #print('copyright:copyright_usage: %s') % requests.get(base+'/api/meta-data/'+id, auth=auth).json().get('value')
            pass
        elif (key == 'madek_core:copyright_notice'):
            copyright_notice = requests.get(base+'/api/meta-data/'+id, auth=auth).json().get('value')
            #print('madek_core:copyright_notice: %s') % copyright_notice
            new_entry['copyright_notice'] = copyright_notice
    
    
    # create or update entry
    obj, created = Entry.objects.update_or_create(
        remote_uuid = entry.get('id'), defaults=new_entry)
    
    # save image
    image_href = entry['_json-roa']['relations']['media-file'].get('href')
    image_request = requests.get(base + image_href, auth=auth)
    image = image_request.json()
    image_data_request = requests.get(base + image['_json-roa']['relations']['data-stream']['href'], stream=True, auth=auth)
    
    if image_data_request.status_code == 200:
        f = tempfile.NamedTemporaryFile(delete=False)
        with open(f.name, 'wb') as f:
            image_data_request.raw.decode_content = True
            shutil.copyfileobj(image_data_request.raw, f)
            #for chunk in image_data_request:
            #    f.write(chunk)
            f.close()
        # save entry
        with open(f.name, 'r') as f:
            
            print(image.get('filename'))
            obj.image.save(image.get('filename'), File(f), save=True)
            
        f.close()
        os.unlink(f.name)
            
    # set licenses, authors
    print("Entry: %s") % obj
    obj.license.set(license_objs)
    obj.author.set(author_objs)
        

url = base + '/api/media-entries/?collection_id=' + collection_id

while (True):
    r = requests.get(url, auth=auth)

    collection_data = r.json()['_json-roa']['collection']

    relations = collection_data.get('relations')
    next_page = collection_data.get('next')

    # iterate page
    for key, value in relations.iteritems():

        get_entry(key, value.get('href'))

        print('########################')

        # sys.exit(0) # exit after first item (debugging)


    if (next_page == None):
        break
    else:
        url = base + collection_data['next']['href']
        print ("page at: %s") % url
    
print('done')
# Out:
# Madek: a2cee86f-6965-4c6c-a2a2-2bee6e5af1dd
# /home/stahl/icst/soundcolourspace/sound-colour-space/env/lib/python2.7/site-packages/django/db/models/fields/files.py:93: RemovedInDjango110Warning: Backwards compatibility for storage backends without support for the `max_length` argument in Storage.get_available_name() will be removed in Django 1.10.
#   self.name = self.storage.save(name, content, max_length=self.field.max_length)
# 13xx_odington_walter_CSI_184_1_Circles.jpg
# Entry: Circles [f694aa76-1ea6-4909-8dbb-02c70975fd92]
# ########################
# Madek: 15682539-c0cc-406c-b3f8-3822c5ac4dc1
# 09xx_Boethius_DeInstitutioneArithmetica_Mh_1_f_4r_detail_02.jpg
# Entry: Number triangle (2 : 3) [af9f3c58-8e0c-4d1d-8d07-17115ce6d7f3]
# ########################
# Madek: 0b9482da-0570-4984-bb0a-46fc3dfe9437
# 09xx_Boethius_DeInstitutioneArithmetica_Mh_1_f_4v_detail_02.jpg
# Entry: Number triangle (4 : 5) [f49373dd-9445-4181-84c3-09744aa33516]
# ########################
# Madek: b8d41539-f57c-4792-946a-6aa5b06c6a0c
# 09xx_Boethius_DeInstitutioneArithmetica_Mh_1_f_4v_detail_01.jpg
# Entry: Number triangle (3 : 4) [883d2ec8-b5fd-4277-91f1-38e5e21c3f7c]
# ########################
# Madek: b5f07222-ce22-4d75-a102-a0aff0402bf4
# 09xx_Boethius_DeInstitutioneArithmetica_Mh_1_f_8v_detail_01_b.jpg
# Entry: Tetrahedron (detail) [2cc470e9-03fd-480b-9054-6c1d6ba69694]
# ########################
# Madek: ca02b832-6db2-402a-b123-0f9a77507fc0
# 09xx_Boethius_DeInstitutioneArithmetica_Mh_1_f_8v_detail_01_a.jpg
# Entry: Tetrahedron [e5750a23-7ea4-41f9-9ce1-a2801bcae46a]
# ########################
# Madek: 31a3a582-ff97-436b-9fe2-0f8ae6c58bdd
# 09xx_Boethius_DeInstitutioneArithmetica_Mh_1_f_8v_detail_02_b.jpg
# Entry: Figurate numbers (2) [798283f3-e499-4d09-9511-ff7d90f6f234]
# ########################
# Madek: f6645267-83da-41e3-918e-6a6e50eb9b79
# 09xx_Boethius_DeInstitutioneArithmetica_Mh_1_f_8v_detail_02_a.jpg
# Entry: Figurate numbers (1) [152d2335-9993-430d-874a-d33e7b932c37]
# ########################
# Madek: 81e3951b-9b8c-4532-867c-c186115589fc
# Entry: Mysterium Aeternitatis [6f6c3e64-6b58-43ca-8b3b-9bf864d7eb6e]
# ########################
# Madek: 0befcbd7-094b-4923-85b3-ee7fc5bb93db
# 1680_PhiloMus_A_B__Synopsis_of_Vocal_Musick_1.jpg
# Entry: Diatonic scales: F major and C major [39e245b7-16a8-430d-9e38-aef63331368a]
# ########################
# Madek: c0c699d0-d888-452c-96e4-34b7fb4b4c06
# 1672_Salmon_1213_WhirligigOctaveCircle_gouk_130_4_16_detail.jpg
# Entry: Whirligig Octave Circle [1178a730-ba29-4c14-8978-45ae9ecbc8d0]
# ########################
# Madek: 089c7549-ead7-40ee-83fb-827b6ba62a57
# 1665_newton__manus_231_109v_detail_02.jpg
# Entry: Diatonic Circles (detail) [eb973de9-ee84-4f51-bb2f-79c6b33f8182]
# ########################
# Madek: 0d7afa09-6dea-44f5-8027-f1ca74b0df6e
# 1680_PhiloMus_A_B__Synopsis_of_Vocal_Musick_2.jpg
# Entry: Diatonic scale: microtonal graduation [9ebc6fd9-1b90-4723-bf0a-06c9aab4b9e6]
# ########################
# Madek: b15d538c-802f-49a4-9ffb-754046e3ec85
# 1665_newton__manus_231_109v_detail_01.jpg
# Entry: Diatonic circles (2) [21d034e2-14e8-49b6-8709-bf4513e45406]
# ########################
# Madek: b68b20ce-c26a-48d9-a78f-f9abfcb1867b
# 1675_Newton_ColourSpectrumAndMusicalScale_gage_1999_140_Fig_060.jpg
# Entry: Colour Spectrum and Musical Scale [968fddb4-10f9-4ee4-a87d-a0f02862b51d]
# ########################
# Madek: 4fca7de9-a3b6-4581-a31b-b937d1acf9c8
# 1675_newton_spectreMonochord_NATP00287-4.jpg
# Entry: Spectre Monochord [f180837c-851d-4bc6-a1b9-133fa8f7d45b]
# ########################
# Madek: 64d1961f-f7e7-4270-888b-4f872f9838bf
# 1672_Salmon_1213_WhirligigOctaveCircle_gouk_130_4_16.jpg
# Entry: Whirligig Octave Circle [a98d9c3c-e656-4f6e-850f-4e20f806a130]
# ########################
# Madek: 4cac8395-2832-4e82-97bb-d73bd2ba810c
# 1675_newton_colourspectrumandmusicalscale_gage_1999_140_fig_060_detail.jpg
# Entry: Colour Spectrum and Musical Scale [b1b75a48-f3ac-4166-9132-fc5873a9e0a7]
# ########################
# page at: http://medienarchiv.zhdk.ch/api/media-entries/?collection_id=73114b11-08de-42a9-ba36-864d9c1b5641&page=9
# Madek: ed71dd26-1faf-4dda-8d51-a524c1ebd80d
# 1684_anonymous__themusicallcompass_herissone_2000_musictheory_085.jpg
# Entry: The Musicall Compass [98b81891-de66-4a7f-825b-c50619d7a046]
# ########################
# Madek: 711f380f-2764-45e9-896d-00025c9d9de3
# 1726_rameau__NouveauSysteme_24_TableDesProgressions.jpg
# Entry: Table des Progressions [b810cdb1-99c5-441c-891c-bc3e68543bfd]
# ########################
# Madek: 0241cf31-60ef-438f-b2d2-9b0322977053
# 1704_newton_Opticks_Book_I_Part_II_Plate_1_Fig_4_monochordSpectre.jpg
# Entry: Monochord Spectre [e642cac4-e6fc-476c-bb32-01e36c21b712]
# ########################
# Madek: 0f06a5ec-d766-4ff5-aa4e-9e7f0f1a4647
# 1739_Euler__Tentamen_279_ChromScalePowers.jpg
# Entry: Chromatic Scale Powers [16d6357f-298d-4daa-915c-ac105e288aee]
# ########################
# Madek: c7f6e83a-17df-466a-9ce2-ec87e886d47b
# 1739_Euler__Tentamen_147_ChromaticScale.jpg
# Entry: Chromatic Scale [a13f39d7-460f-4979-a0f3-a7200ca989ec]
# ########################
# Madek: 902dac17-87fa-4a11-b2e2-b5bbde0c4cfe
# 1852_drobisch__121_skrews.jpg
# Entry: Pitch Helix [21917bd2-319d-408a-b3c5-c62e22c35d60]
# ########################
# Madek: 656c8876-c12e-4e67-9b44-90cd5297e62c
# 1834_opelt_SchraubenLinie.jpg
# Entry: Pitch Helix [60d1ed08-d5ec-4e05-8b17-287e3ad5cb82]
# ########################
# page at: http://medienarchiv.zhdk.ch/api/media-entries/?collection_id=73114b11-08de-42a9-ba36-864d9c1b5641&page=10
# done

# %% [markdown]
# # Import files from directory

# %% [markdown]
# # Search & Replace

# %%
import re
entries = Entry.objects.all()
total = 0
for e in entries:
    #e.title = e.title.replace('.gif', '')
    #e.save()
    
    # match 4 digits at start of title + 1 whitespace
    m = re.findall('^(\d{4}.)', e.title)
    if m:
        total = total + 1
        #print e.title
        #print e.title.replace(m[0], '')
        e.title = e.title.replace(m[0], '')
        #e.save()
print total

# %% [markdown]
# # SearchQuery

# %%
from haystack.query import SearchQuerySet, EmptySearchQuerySet
from haystack.inputs import Raw
from itertools import chain
results = []
#query = '*mono* OR zarlino'
#query = 'newton'
#query = '1675'
query = 'Fludd OR newton'

author = EmptySearchQuerySet()
#author = SearchQuerySet().models(Entry).filter(author=Raw(query))
portrayed_object_date = EmptySearchQuerySet()
#portrayed_object_date = SearchQuerySet().models(Entry).filter(portrayed_object_date=Raw(query))
auto = EmptySearchQuerySet()
#auto = SearchQuerySet().models(Entry).auto_query(query)
combined = EmptySearchQuerySet()
#combined = SearchQuerySet().models(Entry).autocomplete(title_auto=query).filter(text=Raw(query))
raw_full = EmptySearchQuerySet()
raw_full = SearchQuerySet().models(Entry).filter(text=Raw(query))

results =  list(chain(author, portrayed_object_date, auto, combined, raw_full))

if not results:
    print 'None found.'
else:
    print 'Found %s.' % len(results)
    for r in results:
        print '%d %s %s %s' % (r.portrayed_object_date, r.author ,r.title, r.tags)

# %% [markdown]
# # Local Import

# %%
import os
from django.core.files import File
for f in sorted(os.listdir('temp')):
    if f.endswith(".jpg") or f.endswith(".gif"):
        img = open('temp/' + f)
        dimg = File(img)
        e = Entry(title=f)
        e.save() # save so we have an uuid for the image path
        e.image.save(f, dimg) # image path will be overwritten by model
        e.save()

# %% [markdown]
# # Set author

# %%
a = "thius"
entries = Entry.objects.filter(title__icontains=a)
author = Author.objects.get(last_name__icontains=a)
print (author)
entries.update(author=author)
print (entries)

# %%
up = 0
for e in Entry.objects.all():
    t = e.title
    y = t.split('_')[0]
    if any(char.isdigit() for char in y):
        e.portrayed_object_date = y
        e.save()
        up = up + 1
print ('updated %d entries.' % up)
